# %% [markdown]
# <a href="https://colab.research.google.com/github/oluwatunbi/Appendix-cancer-pred/blob/main/Predictchurn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import packages needed
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Shows plots in jupyter notebook
# %matplotlib inline

# %%
# load data
df = pd.read_csv('/content/drive/MyDrive/data_for_predictions.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                id  cons_12m  cons_gas_12m  \
# 0           0  24011ae4ebbe3035111d65fa7c15bc57  0.000000      4.739944
# 1           1  d29c2c54acc38ff3c0614d0a653813dd  3.668479      0.000000
# 2           2  764c75f661154dac3a6c254cd082ea7d  2.736397      0.000000
# 3           3  bba03439a292a1e166f80264c16191cb  3.200029      0.000000
# 4           4  149d57cf92fc41cf94415803a877cb4b  3.646011      0.000000
#
#    cons_last_month  forecast_cons_12m  forecast_discount_energy  \
# 0         0.000000           0.000000                       0.0
# 1         0.000000           2.280920                       0.0
# 2         0.000000           1.689841                       0.0
# 3         0.000000           2.382089                       0.0
# 4         2.721811           2.650065                       0.0
#
#    forecast_meter_rent_12m  forecast_price_energy_off_peak  \
# 0                 0.444045                        0.114481
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 64 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Unnamed: 0                                  14606 non-null  int64
#  1   id                                          14606 non-null  object
#  2   cons_12m                                    14606 non-null  float64
#  3   cons_gas_12m                                14606 non-null  float64
#  4   cons_last_month                             14606 non-null  float64
#  5   forecast_cons_12m                           14606 non-null  float64
#  6   forecast_discount_energy                    14606 non-null  float64
#  7   forecast_meter_rent_12m                     14606 non-null  float64
#  8   forecast_price_energy_off_peak              14606 non-null  float64
# ...

# %%
# create new df
df_new = df.copy()
print(df_new.shape)
# Out:
# (14606, 64)

# %%
# Get the data that is a string since randomforest work with int and float
for label, content in df_new.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# id

# %%
# convert id into pandas categories
df_new = pd.get_dummies(df_new, columns=['id'])

# %%
for label, content in df_new.items():
    if pd.api.types.is_string_dtype(content):
        print(label)

# %% [markdown]
# Sample Data
#
# The first thing we want to do is split our dataset into training and test samples. The reason why we do this, is so that we can simulate a real life situation by generating predictions for our test sample, without showing the predictive model these data points. This gives us the ability to see how well our model is able to generalise to new data, which is critical.
#
# A typical % to dedicate to testing is between 20-30, for this example we will use a 75-25% split between train and test respectively.

# %%
# split the data into x and y
x = df_new.drop("churn" , axis = 1)
y = df_new["churn"]

print(x.shape)
print(y.shape)
# Out:
# (14606, 14668)
# (14606,)

# %%
# split into train and test data
np.random.seed(42)

X_train, X_test, Y_train, Y_test = train_test_split (x,
                                                    y,
                                                    test_size = 0.25)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (10954, 14668)
# (10954,)
# (3652, 14668)
# (3652,)

# %%
# Train the model using random forest
model = RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test, Y_test)
# Out:
# 0.901697699890471

# %% [markdown]
# ##Evaluation
#
# Now let's evaluate how well this trained model is able to predict the values of the test dataset.

# %%
# Generate predictions here!
y_preds = model.predict(X_test)
print(y_preds)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# Calculate performance metrics here!
print(metrics.classification_report(Y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      3286
#            1       0.89      0.02      0.04       366
#
#     accuracy                           0.90      3652
#    macro avg       0.90      0.51      0.50      3652
# weighted avg       0.90      0.90      0.86      3652
